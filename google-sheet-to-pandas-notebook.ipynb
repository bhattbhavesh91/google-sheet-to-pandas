# %%
import pandas as pd

# %%
gsheetid = "1PwzQ6ZuoQaaNjPJ0yHiTIeFUKX1n1LN7gg5k9auNFXU"
sheet_name = "Data"

# %%
gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)

# %%
gsheet_url
# Out:
# 'https://docs.google.com/spreadsheets/d/1PwzQ6ZuoQaaNjPJ0yHiTIeFUKX1n1LN7gg5k9auNFXU/gviz/tq?tqx=out:csv&sheet=Data'

# %%
df = pd.read_csv(gsheet_url)

# %%
df
# Out:
#    col1 col2
# 0     1    a
# 1     2    b
# 2     3    c
